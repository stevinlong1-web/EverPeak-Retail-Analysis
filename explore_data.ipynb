# %% [markdown]
# # EverPeak Retail Analysis

# %% [markdown]
# ## Load the Dataset
# Load the dataset and take a first look at its structure and contents.

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/everpeak_retail.csv")
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5008 entries, 0 to 5007
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5008 non-null   int64
#  1   order_date        5000 non-null   str
#  2   customer_id       5008 non-null   int64
#  3   product_category  5008 non-null   str
#  4   price             5008 non-null   int64
#  5   quantity          5008 non-null   int64
#  6   order_value       5008 non-null   float64
#  7   payment_method    5008 non-null   str
#  8   city              4908 non-null   str
#  9   state             4908 non-null   str
#  10  customer_age      4858 non-null   float64
# dtypes: float64(2), int64(4), str(5)
# memory usage: 430.5 KB
#    order_id  order_date  customer_id product_category  price  quantity  \
# 0         1  2024-02-02         2616           Sports    269        50
# 1         2  2024-10-10         1736          Grocery     66         0
# ...

# %% [markdown]
# ## Basic Exploration

# %%
# explore numerical columns
df.describe()
# Out:
#           order_id  customer_id         price     quantity    order_value  \
# count  5008.000000  5008.000000   5008.000000  5008.000000    5008.000000
# mean   2504.500000  1988.362420    756.187500    21.871406   10071.557268
# std    1445.829404   569.889309   1172.528065    63.303488   12398.052023
# min       1.000000  1000.000000     12.000000     0.000000      12.000000
# 25%    1252.750000  1495.000000    218.750000     0.000000    3096.250000
# 50%    2504.500000  1988.000000    457.000000     0.000000   10339.490000
# 75%    3756.250000  2475.000000    847.000000    22.000000   13159.237500
# max    5008.000000  2999.000000  36708.000000  1266.000000  303824.000000
#
#        customer_age
# count   4858.000000
# mean      43.728695
# std       77.130195
# min     -999.000000
# 25%       34.000000
# 50%       49.000000
# 75%       65.000000
# max       80.000000

# %%
# explore date column
df["order_date"].min(), df["order_date"].max()
# Out:
# ('2024-01-01', '2026-12-30')

# %%
df.isna().sum()
# Out:
# order_id              0
# order_date            8
# customer_id           0
# product_category      0
# price                 0
# quantity              0
# order_value           0
# payment_method        0
# city                100
# state               100
# customer_age        150
# dtype: int64

# %%
df.groupby("product_category")["order_value"].median()
# Out:
# product_category
# ?               3016.00
# Beauty          7047.00
# Electronics    12483.88
# Fashion         8077.50
# Grocery         4131.00
# Home           10749.59
# Sports         10557.67
# Toys            8228.00
# Name: order_value, dtype: float64

# %%
df.groupby("product_category")["order_value"].sum().plot(kind="bar")
plt.show()
